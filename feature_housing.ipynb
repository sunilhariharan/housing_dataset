# %% [markdown]
# # Practice problem

# %%
import numpy as np
import pandas as pd
import math

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
#import training dataset
train_df = pd.read_csv('/Users/sunilhariharan/Downloads/kaggle1stcomp/train.csv', index_col='ID')

#see the columns in our data
train_df.info()

# take a look at the head of the dataset
train_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 1 to 506
# Data columns (total 14 columns):
# crim       333 non-null float64
# zn         333 non-null float64
# indus      333 non-null float64
# chas       333 non-null int64
# nox        333 non-null float64
# rm         333 non-null float64
# age        333 non-null float64
# dis        333 non-null float64
# rad        333 non-null int64
# tax        333 non-null int64
# ptratio    333 non-null float64
# black      333 non-null float64
# lstat      333 non-null float64
# medv       333 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 39.0 KB
#        crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# ID
# 1   0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2   0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 4   0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5   0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 7   0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
#
#      black  lstat  medv
# ID
# 1   396.90   4.98  24.0
# 2   396.90   9.14  21.6
# 4   394.63   2.94  33.4
# 5   396.90   5.33  36.2
# 7   395.60  12.43  22.9

# %% [markdown]
# ## Create train test split (70-30 %)

# %%
#create our X and y
X = train_df.drop('medv', axis=1)
y = train_df['medv']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %% [markdown]
# ## Fit a simple Linear regression model

# %%
lr_model = LinearRegression(fit_intercept=True)
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# R2 score
print('Training score: {}'.format(lr_model.score(X_train, y_train)))
print('Test score: {}'.format(lr_model.score(X_test, y_test)))
# Out:
# Training score: 0.7268827869293253
# Test score: 0.7254687959254545

# %% [markdown]
# ## Get RMSE for test and train set

# %%
y_train_pred = lr_model.predict(X_train)
train_mse = mean_squared_error(y_train, y_train_pred)
train_rmse = math.sqrt(train_mse)
print('RMSE for train: {}'.format(train_rmse))

y_pred_test = lr_model.predict(X_test)
test_mse = mean_squared_error(y_test, y_pred_test)
test_rmse = math.sqrt(test_mse)

print('RMSE for test: {}'.format(test_rmse))
# Out:
# RMSE for train: 4.862113965519083
# RMSE for test: 4.587100299689446

# %%
def train_test_rmse(my_model, X_train, y_train, X_test, y_test):
    y_train_pred = my_model.predict(X_train)
    train_mse = mean_squared_error(y_train, y_train_pred)
    train_rmse = math.sqrt(train_mse)
    print('RMSE for train: {}'.format(train_rmse))

    y_pred_test = my_model.predict(X_test)
    test_mse = mean_squared_error(y_test, y_pred_test)
    test_rmse = math.sqrt(test_mse)

    print('RMSE for test: {}'.format(test_rmse))
    
    print('Accuracies: Train: {},    Test: {}'.format(
        my_model.score(X_train, y_train),
        my_model.score(X_test, y_test))
         )
    
    
    return train_rmse, test_rmse

# %%
train_test_rmse(lr_model, X_train, y_train, X_test, y_test)
# Out:
# RMSE for train: 4.862113965519083
# RMSE for test: 4.587100299689446
# Accuracies: Train: 0.7268827869293253,    Test: 0.7254687959254545
# (4.862113965519083, 4.587100299689446)

# %% [markdown]
# ## Standardization

# %%
d = 2
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=d)),
    ('model', LinearRegression())
]

pipeline = Pipeline(steps)

pipeline.fit(X_train, y_train)
print('degree: {}'.format(d))
train_test_rmse(pipeline, X_train, y_train, X_test, y_test)
print('\n\n\n')
# Out:
# degree: 2
# RMSE for train: 2.130161481510501
# RMSE for test: 6.387787364377362
# Accuracies: Train: 0.9475767600691032,    Test: 0.4676268497188017

# %%
# Change degree to 5 and see what happens

# %% [markdown]
# ## L2 or Ridge regression

# %%
a = 5
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=2)),
    ('model', Ridge(alpha=a, fit_intercept=True))
]

ridge_pipe = Pipeline(steps)
ridge_pipe.fit(X_train, y_train)
print(a)
train_test_rmse(ridge_pipe, X_train, y_train, X_test, y_test)
print('\n\n')
# Out:
# 5
# RMSE for train: 2.51697524269054
# RMSE for test: 3.5520485232100354
# Accuracies: Train: 0.9268091667908349,    Test: 0.8353836295367756

# %% [markdown]
# ## L1 or Lasso regularization

# %%
alp = 0.022
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=2)),
    ('model', Lasso(alpha=alp, fit_intercept=True))
]

lasso_pipe = Pipeline(steps)
print(alp)
lasso_pipe.fit(X_train, y_train)
train_test_rmse(lasso_pipe, X_train, y_train, X_test, y_test)
print('\n\n')
# Out:
# 0.022
# RMSE for train: 2.507718381874795
# RMSE for test: 3.4897355548326274
# Accuracies: Train: 0.9273465351903244,    Test: 0.8411086413402027

# %% [markdown]
# ## Elastic Net

# %%
X = train_df.drop('medv', axis=1)
y = train_df['medv']

# %%
def my_elas_func(X_train,y_train,X_test,y_test):
    alpha = 0.0265
    steps = [
        ('scalar', StandardScaler()),
        ('poly', PolynomialFeatures(degree=2)),
        ('model', ElasticNet(alpha=alpha, fit_intercept=True))
    ]
    elastic_pipe = Pipeline(steps)
    elastic_pipe.fit(X_train, y_train)
    print(alpha)
    train_test_rmse(elastic_pipe, X_train, y_train, X_test, y_test)
    print('\n\n')

# %%
my_elas_func(X_train,y_train,X_test,y_test)
# Out:
# 0.0265
# RMSE for train: 2.557614530114663
# RMSE for test: 3.487369795949514
# Accuracies: Train: 0.9244265959197951,    Test: 0.8413239993367233

# %%
#import training dataset
test_df = pd.read_csv('/Users/sunilhariharan/Downloads/kaggle1stcomp/test.csv', index_col='ID')

#see the columns in our data
test_df.info()

# take a look at the head of the dataset
test_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 3 to 505
# Data columns (total 13 columns):
# crim       173 non-null float64
# zn         173 non-null float64
# indus      173 non-null float64
# chas       173 non-null int64
# nox        173 non-null float64
# rm         173 non-null float64
# age        173 non-null float64
# dis        173 non-null float64
# rad        173 non-null int64
# tax        173 non-null int64
# ptratio    173 non-null float64
# black      173 non-null float64
# lstat      173 non-null float64
# dtypes: float64(10), int64(3)
# memory usage: 18.9 KB
#        crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# ID
# 3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
#
#     ptratio   black  lstat
# ID
# 3      17.8  392.83   4.03
# 6      18.7  394.12   5.21
# 8      15.2  396.90  19.15
# 9      15.2  386.63  29.93
# 10     15.2  386.71  17.10

# %%
y_test_pred = elastic_pipe.predict(test_df)

# %%
type(y_test_pred)
print(len(y_test_pred))
# Out:
# 173

# %%
# y_test_pred
# submission_df = pd.Dataframe
submission_df = pd.DataFrame(test_df.index)
submission_df['medv'] = y_test_pred
submission_df.set_index('ID', inplace=True)
submission_df.head()
# type(ids)
# submission_df = pd.join(ids, pd.Series(y_test_pred))
# Out:
#          medv
# ID
# 3   32.168273
# 6   25.311255
# 8   16.184712
# 9   16.765992
# 10  17.247958

# %%
submission_df.to_csv('/Users/sunilhariharan/Downloads/kaggle1stcomp/mysub.csv')

# %%
col_list=list(X_train.columns)

# %%
col_list
# Out:
# ['crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'black',
#  'lstat']

# %%
def select_cols(df,col_list): 
    return df[[item for item in col_list]]

# %%
for i in range(len(col_list)):
    feature_list=[]
    curr_feature_name=col_list[i]
    feature_list.append(curr_feature_name)
    print(feature_list)
    
    new_X_train=select_cols(X_train,feature_list)
    new_X_test=select_cols(X_test,feature_list)
    my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['crim']
# 0.0265
# RMSE for train: 8.289624058011556
# RMSE for test: 7.903731207468503
# Accuracies: Train: 0.20609511479140652,    Test: 0.18495879270463145
#
#
#
# ['zn']
# 0.0265
# RMSE for train: 8.651890594263087
# RMSE for test: 8.336625437244807
# Accuracies: Train: 0.135189723494339,    Test: 0.09323276180977091
#
#
#
# ['indus']
# 0.0265
# RMSE for train: 7.813931551377416
# RMSE for test: 8.058917578775905
# Accuracies: Train: 0.2945958525788539,    Test: 0.152638612117742
#
#
#
# ['chas']
# 0.0265
# RMSE for train: 9.087170809778211
# RMSE for test: 8.7167044868434
# Accuracies: Train: 0.04598283972122785,    Test: 0.008666259609597327
#
#
#
# ['nox']
# 0.0265
# RMSE for train: 8.254165981364064
# RMSE for test: 8.49868800944949
# Accuracies: Train: 0.21287229428121623,    Test: 0.0576352882230049
#
#
#
# ['rm']
# 0.0265
# RMSE for train: 6.351671207673917
# RMSE for test: 5.130434748943688
# Accuracies: Train: 0.5339045950662946,    Test: 0.6565815853278247
#
#
#
# ['age']
# 0.0265
# RMSE for train: 8.51686196067812
# RMSE for test: 8.362641759682154
# Accuracies: Train: 0.16197298229954193,    Test: 0.08756438696145487
#
#
#
# ['dis']
# 0.0265
# RMSE for train: 8.797338580524467
# RMSE for test: 8.75004596377073
# Accuracies: Train: 0.10586845444222626,    Test: 0.0010680338801226652
#
#
#
# ['rad']
# 0.0265
# RMSE for train: 8.681821548040691
# RMSE for test: 8.007328123488115
# Accuracies: Train: 0.1291958035252626,    Test: 0.16345271728815547
#
#
#
# ['tax']
# 0.0265
# RMSE for train: 8.232261857827279
# RMSE for test: 8.06125486961484
# Accuracies: Train: 0.21704436104693678,    Test: 0.15214702818185644
#
#
#
# ['ptratio']
# 0.0265
# RMSE for train: 8.320007793877593
# RMSE for test: 7.267928365655063
# Accuracies: Train: 0.2002646928926236,    Test: 0.3108138860751414
#
#
#
# ['black']
# 0.0265
# RMSE for train: 8.772044679712641
# RMSE for test: 8.316281026901759
# Accuracies: Train: 0.11100263492570794,    Test: 0.09765304803306085
#
#
#
# ['lstat']
# 0.0265
# RMSE for train: 5.7015638733899
# RMSE for test: 4.992417587680615
# Accuracies: Train: 0.6244335477695289,    Test: 0.6748100980019727

# %%
for i in range(len(col_list)):
    feature_list=['lstat']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'crim']
# 0.0265
# RMSE for train: 5.416135104140316
# RMSE for test: 4.968795731820715
# Accuracies: Train: 0.661095151546357,    Test: 0.677880120074376
#
#
#
# ['lstat', 'zn']
# 0.0265
# RMSE for train: 5.682551964550244
# RMSE for test: 5.040205765779965
# Accuracies: Train: 0.6269340303482236,    Test: 0.6685547680294401
#
#
#
# ['lstat', 'indus']
# 0.0265
# RMSE for train: 5.584652529629084
# RMSE for test: 4.675696457448462
# Accuracies: Train: 0.6396777193779135,    Test: 0.7147616859141159
#
#
#
# ['lstat', 'chas']
# 0.0265
# RMSE for train: 5.399517445009608
# RMSE for test: 5.132539009226015
# Accuracies: Train: 0.6631716010641816,    Test: 0.6562998197612733
#
#
#
# ['lstat', 'nox']
# 0.0265
# RMSE for train: 5.59085340599285
# RMSE for test: 4.678245617264092
# Accuracies: Train: 0.6388771129559032,    Test: 0.7144505809205304
#
#
#
# ['lstat', 'rm']
# 0.0265
# RMSE for train: 4.787110802834541
# RMSE for test: 3.3835278447705925
# Accuracies: Train: 0.7352440291215128,    Test: 0.8506329678368497
#
#
#
# ['lstat', 'age']
# 0.0265
# RMSE for train: 5.425725818533114
# RMSE for test: 4.38183858544167
# Accuracies: Train: 0.6598938456916529,    Test: 0.749488312284576
#
#
#
# ['lstat', 'dis']
# 0.0265
# RMSE for train: 5.295281370457797
# RMSE for test: 4.323340563919022
# Accuracies: Train: 0.6760508183644698,    Test: 0.7561323812729054
#
#
#
# ['lstat', 'rad']
# 0.0265
# RMSE for train: 5.250603275183008
# RMSE for test: 5.129294377764084
# Accuracies: Train: 0.6814942963403521,    Test: 0.6567342355251242
#
#
#
# ['lstat', 'tax']
# 0.0265
# RMSE for train: 5.290193047810235
# RMSE for test: 4.978618047131158
# Accuracies: Train: 0.6766730953976334,    Test: 0.6766053281689102
#
#
#
# ['lstat', 'ptratio']
# 0.0265
# RMSE for train: 5.5355061099442135
# RMSE for test: 4.3357182711417614
# Accuracies: Train: 0.6459916771288059,    Test: 0.7547339982635761
#
#
#
# ['lstat', 'black']
# 0.0265
# RMSE for train: 5.568777471461817
# RMSE for test: 5.005763618387909
# Accuracies: Train: 0.6417233281382164,    Test: 0.6730691397153772

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'crim']
# 0.0265
# RMSE for train: 4.406721134952346
# RMSE for test: 3.351773059883591
# Accuracies: Train: 0.7756480025128301,    Test: 0.8534234639388154
#
#
#
# ['lstat', 'rm', 'zn']
# 0.0265
# RMSE for train: 4.636555320098605
# RMSE for test: 3.4533199395390755
# Accuracies: Train: 0.7516353997446655,    Test: 0.8444074226937768
#
#
#
# ['lstat', 'rm', 'indus']
# 0.0265
# RMSE for train: 4.263882771470475
# RMSE for test: 3.901458376324602
# Accuracies: Train: 0.7899564665570812,    Test: 0.8014045940042167
#
#
#
# ['lstat', 'rm', 'chas']
# 0.0265
# RMSE for train: 4.4653463061579854
# RMSE for test: 3.8286702367215617
# Accuracies: Train: 0.7696389256092905,    Test: 0.8087457183657727
#
#
#
# ['lstat', 'rm', 'nox']
# 0.0265
# RMSE for train: 4.526322163475639
# RMSE for test: 3.6967287820060046
# Accuracies: Train: 0.7633046492910244,    Test: 0.8217003790648605
#
#
#
# ['lstat', 'rm', 'age']
# 0.0265
# RMSE for train: 4.41701272418665
# RMSE for test: 3.4035793007640796
# Accuracies: Train: 0.7745988620232868,    Test: 0.8488573648744531
#
#
#
# ['lstat', 'rm', 'dis']
# 0.0265
# RMSE for train: 4.255225994300914
# RMSE for test: 3.3689834899998763
# Accuracies: Train: 0.790808485411353,    Test: 0.8519143392283466
#
#
#
# ['lstat', 'rm', 'rad']
# 0.0265
# RMSE for train: 4.039606892810285
# RMSE for test: 3.528142076541509
# Accuracies: Train: 0.8114714997219842,    Test: 0.8375920167349028
#
#
#
# ['lstat', 'rm', 'tax']
# 0.0265
# RMSE for train: 3.962315925442876
# RMSE for test: 3.5071734453348338
# Accuracies: Train: 0.8186168233652532,    Test: 0.839516742691531
#
#
#
# ['lstat', 'rm', 'ptratio']
# 0.0265
# RMSE for train: 4.497069382774577
# RMSE for test: 3.3302255378002448
# Accuracies: Train: 0.7663541993155834,    Test: 0.8553019974930587
#
#
#
# ['lstat', 'rm', 'black']
# 0.0265
# RMSE for train: 4.642928399992768
# RMSE for test: 3.3476289514654356
# Accuracies: Train: 0.7509521617950081,    Test: 0.8537856922494214

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'crim']
# 0.0265
# RMSE for train: 4.198261966471088
# RMSE for test: 3.3314266421894234
# Accuracies: Train: 0.79637182322959,    Test: 0.8551976029134793
#
#
#
# ['lstat', 'rm', 'ptratio', 'zn']
# 0.0265
# RMSE for train: 4.446533426368245
# RMSE for test: 3.2717738093118722
# Accuracies: Train: 0.7715758978692426,    Test: 0.860336865359188
#
#
#
# ['lstat', 'rm', 'ptratio', 'indus']
# 0.0265
# RMSE for train: 4.057163236378224
# RMSE for test: 3.6893508036594644
# Accuracies: Train: 0.8098292292496072,    Test: 0.8224113741545033
#
#
#
# ['lstat', 'rm', 'ptratio', 'chas']
# 0.0265
# RMSE for train: 4.13843370065814
# RMSE for test: 3.492526387797163
# Accuracies: Train: 0.8021341670271829,    Test: 0.8408544005534452
#
#
#
# ['lstat', 'rm', 'ptratio', 'nox']
# 0.0265
# RMSE for train: 4.113223657120427
# RMSE for test: 3.5531963095735244
# Accuracies: Train: 0.8045374980105907,    Test: 0.8352772261748058
#
#
#
# ['lstat', 'rm', 'ptratio', 'age']
# 0.0265
# RMSE for train: 4.126634841106781
# RMSE for test: 3.1595599620520294
# Accuracies: Train: 0.8032608073602003,    Test: 0.869752785005428
#
#
#
# ['lstat', 'rm', 'ptratio', 'dis']
# 0.0265
# RMSE for train: 3.887552348886073
# RMSE for test: 3.447916771086621
# Accuracies: Train: 0.8253971597697113,    Test: 0.8448939314639552
#
#
#
# ['lstat', 'rm', 'ptratio', 'rad']
# 0.0265
# RMSE for train: 3.860228858080481
# RMSE for test: 3.3689610275369555
# Accuracies: Train: 0.8278429113057435,    Test: 0.8519163139234348
#
#
#
# ['lstat', 'rm', 'ptratio', 'tax']
# 0.0265
# RMSE for train: 3.750121772110856
# RMSE for test: 3.394377035378066
# Accuracies: Train: 0.837523878290528,    Test: 0.8496735494192174
#
#
#
# ['lstat', 'rm', 'ptratio', 'black']
# 0.0265
# RMSE for train: 4.3851238163082815
# RMSE for test: 3.3053862044002655
# Accuracies: Train: 0.7778417097093914,    Test: 0.8574524811475439

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'crim']
# 0.0265
# RMSE for train: 3.957868743922238
# RMSE for test: 3.1740763976297073
# Accuracies: Train: 0.8190237526713948,    Test: 0.868553207375354
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'zn']
# 0.0265
# RMSE for train: 4.092407208917886
# RMSE for test: 3.1266544194285038
# Accuracies: Train: 0.8065109083984929,    Test: 0.872451602314638
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'indus']
# 0.0265
# RMSE for train: 3.973154989540313
# RMSE for test: 3.471804519121671
# Accuracies: Train: 0.8176231050546086,    Test: 0.8427372845207344
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'chas']
# 0.0265
# RMSE for train: 3.861598448388116
# RMSE for test: 3.2833554041872115
# Accuracies: Train: 0.8277207286495529,    Test: 0.8593463416660525
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'nox']
# 0.0265
# RMSE for train: 3.9814594320294425
# RMSE for test: 3.232868189753232
# Accuracies: Train: 0.8168599225275588,    Test: 0.8636386669833684
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'dis']
# 0.0265
# RMSE for train: 3.6848418795162323
# RMSE for test: 3.1567708001991224
# Accuracies: Train: 0.8431312207985214,    Test: 0.869982639935511
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'rad']
# 0.0265
# RMSE for train: 3.685128437733261
# RMSE for test: 3.182256402708539
# Accuracies: Train: 0.8431068214961729,    Test: 0.8678748236147098
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax']
# 0.0265
# RMSE for train: 3.6476441849299817
# RMSE for test: 3.103353296062726
# Accuracies: Train: 0.846282349012398,    Test: 0.8743456054163654
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'black']
# 0.0265
# RMSE for train: 4.028397820656014
# RMSE for test: 3.1212249837505524
# Accuracies: Train: 0.8125163032049232,    Test: 0.8728941933089394

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age','tax']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'crim']
# 0.0265
# RMSE for train: 3.598590030615084
# RMSE for test: 3.091424118900504
# Accuracies: Train: 0.8503889921417926,    Test: 0.8753097705822672
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'zn']
# 0.0265
# RMSE for train: 3.5873635533040713
# RMSE for test: 3.115000377330201
# Accuracies: Train: 0.8513210153230878,    Test: 0.8734006577275079
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'indus']
# 0.0265
# RMSE for train: 3.617377156307951
# RMSE for test: 3.299424796280343
# Accuracies: Train: 0.8488227687919938,    Test: 0.8579661988027114
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'chas']
# 0.0265
# RMSE for train: 3.4900032647153023
# RMSE for test: 3.306205836667184
# Accuracies: Train: 0.8592817355586053,    Test: 0.8573817777412264
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'nox']
# 0.0265
# RMSE for train: 3.5444745102370474
# RMSE for test: 3.16368059256774
# Accuracies: Train: 0.8548548532992848,    Test: 0.8694128322070032
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis']
# 0.0265
# RMSE for train: 3.333452876138257
# RMSE for test: 2.9246813528467435
# Accuracies: Train: 0.8716229346337206,    Test: 0.8883979031516006
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'rad']
# 0.0265
# RMSE for train: 3.4978511579069465
# RMSE for test: 3.4424071002796075
# Accuracies: Train: 0.8586481639082595,    Test: 0.8453892453794547
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'black']
# 0.0265
# RMSE for train: 3.551205352917755
# RMSE for test: 3.1982752531894385
# Accuracies: Train: 0.8543030779977923,    Test: 0.8665412915658453

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age','tax','dis']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim']
# 0.0265
# RMSE for train: 3.275219941262844
# RMSE for test: 2.9052386515629545
# Accuracies: Train: 0.8760690603005618,    Test: 0.8898767882793579
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'zn']
# 0.0265
# RMSE for train: 3.2684302750066445
# RMSE for test: 2.9228835696900717
# Accuracies: Train: 0.8765823556238893,    Test: 0.8885350631911471
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'indus']
# 0.0265
# RMSE for train: 3.257363328613276
# RMSE for test: 3.1955956174801683
# Accuracies: Train: 0.8774167280509766,    Test: 0.8667648313668106
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'chas']
# 0.0265
# RMSE for train: 3.243796349206395
# RMSE for test: 3.08414628433717
# Accuracies: Train: 0.8784357248095089,    Test: 0.8758961713071581
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'nox']
# 0.0265
# RMSE for train: 3.2563707468068217
# RMSE for test: 2.9407564216371163
# Accuracies: Train: 0.8774914236713519,    Test: 0.8871677235709231
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'rad']
# 0.0265
# RMSE for train: 3.1581882821756495
# RMSE for test: 3.2081424242068897
# Accuracies: Train: 0.8847675384189316,    Test: 0.865716540002497
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'black']
# 0.0265
# RMSE for train: 3.220353703878829
# RMSE for test: 2.9148622631585903
# Accuracies: Train: 0.88018644544144,    Test: 0.8891460130062998

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age','tax','dis','crim']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'zn']
# 0.0265
# RMSE for train: 3.2013437699127905
# RMSE for test: 2.920095528857279
# Accuracies: Train: 0.88159680307669,    Test: 0.8887476071203622
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'indus']
# 0.0265
# RMSE for train: 3.2000368707471187
# RMSE for test: 3.075380900350856
# Accuracies: Train: 0.8816934558981746,    Test: 0.8766005943670125
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'chas']
# 0.0265
# RMSE for train: 3.1256275680226424
# RMSE for test: 3.0878853134437416
# Accuracies: Train: 0.887131368063024,    Test: 0.8755950772186807
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox']
# 0.0265
# RMSE for train: 3.1909371751599624
# RMSE for test: 2.8864498725657994
# Accuracies: Train: 0.8823653374576675,    Test: 0.8912965615569024
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'rad']
# 0.0265
# RMSE for train: 3.090670288391985
# RMSE for test: 3.018445513496709
# Accuracies: Train: 0.8896419144367623,    Test: 0.881127355693982
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'black']
# 0.0265
# RMSE for train: 3.1457614311428514
# RMSE for test: 3.024712536087839
# Accuracies: Train: 0.8856725885508541,    Test: 0.8806332265664285

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age','tax','dis','crim','nox']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn']
# 0.0265
# RMSE for train: 3.118266535279123
# RMSE for test: 2.882864876886123
# Accuracies: Train: 0.8876623663035237,    Test: 0.8915664150919732
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'indus']
# 0.0265
# RMSE for train: 3.1210723782365566
# RMSE for test: 2.9636389531153116
# Accuracies: Train: 0.887460110617285,    Test: 0.8854049572596332
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'chas']
# 0.0265
# RMSE for train: 2.993125310162765
# RMSE for test: 3.054980433210635
# Accuracies: Train: 0.8964980332345263,    Test: 0.878232298553111
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'rad']
# 0.0265
# RMSE for train: 3.0049032402781717
# RMSE for test: 2.9510182974951498
# Accuracies: Train: 0.8956818713567327,    Test: 0.8863788850115687
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'black']
# 0.0265
# RMSE for train: 3.043199505302007
# RMSE for test: 3.1693647064104815
# Accuracies: Train: 0.8930059436026114,    Test: 0.8689431646040917

# %%
for i in range(len(col_list)):
    feature_list=['lstat','rm','ptratio','age','tax','dis','crim','nox','zn']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=select_cols(X_train,feature_list)
        new_X_test=select_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn', 'indus']
# 0.0265
# RMSE for train: 3.0605017353580837
# RMSE for test: 2.918802548095823
# Accuracies: Train: 0.8917858471797698,    Test: 0.8888461075669345
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn', 'chas']
# 0.0265
# RMSE for train: 2.9383226911503955
# RMSE for test: 3.0689660057783863
# Accuracies: Train: 0.9002534733837531,    Test: 0.877114851699928
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn', 'rad']
# 0.0265
# RMSE for train: 2.9479295626359145
# RMSE for test: 3.0197664838386817
# Accuracies: Train: 0.8996001628593998,    Test: 0.8810232878239332
#
#
#
# ['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn', 'black']
# 0.0265
# RMSE for train: 2.943063184560385
# RMSE for test: 3.197653036153243
# Accuracies: Train: 0.8999313650026717,    Test: 0.8665932146792712

# %%
def reject_cols(df,to_rem_col_list):
    complete_col_list=list(df.columns)
    keep_col_list=[i for i in complete_col_list if i not in to_rem_col_list]
    print('keep_col_list : ',keep_col_list)
    return df[[item for item in keep_col_list]]

# %%
reject_cols(X_train,['crim'])
# Out:
# keep_col_list :  ['zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
#        zn  indus  chas     nox     rm    age     dis  rad  tax  ptratio  \
# ID
# 40   75.0   2.95     0  0.4280  6.595   21.8  5.4011    3  252     18.3
# 441   0.0  18.10     0  0.7400  5.818   92.4  1.8662   24  666     20.2
# 454   0.0  18.10     0  0.7130  7.393   99.3  2.4527   24  666     20.2
# 84   25.0   4.86     0  0.4260  6.167   46.7  5.4007    4  281     19.0
# 262  20.0   3.97     0  0.6470  7.520   89.4  2.1398    5  264     13.0
# 16    0.0   8.14     0  0.5380  5.834   56.5  4.4986    4  307     21.0
# 341   0.0   5.19     0  0.5150  5.968   58.5  4.8122    5  224     20.2
# 343   0.0   1.89     0  0.5180  6.540   59.7  6.2669    1  422     15.9
# 121   0.0  25.65     0  0.5810  5.870   69.7  2.2577    2  188     19.1
# 225   0.0   6.20     0  0.5040  8.266   78.3  2.8944    8  307     17.4
# 61   25.0   5.13     0  0.4530  5.741   66.2  7.2254    8  284     19.7
# 473   0.0  18.10     0  0.5800  6.437   75.0  2.8965   24  666     20.2
# 155   0.0  19.58     1  0.8710  6.129   96.0  1.7494    5  403     14.7
# 227   0.0   6.20     0  0.5040  8.040   86.5  3.2157    8  307     17.4
# 289  52.5   5.32     0  0.4050  6.315   45.6  7.3172    6  293     16.6
# 231   0.0   6.20     0  0.5040  5.981   68.1  3.6715    8  307     17.4
# 179   0.0   4.05     0  0.5100  6.860   74.4  2.9153    5  296     16.6
# 344  55.0   3.78     0  0.4840  6.696   56.4  5.7321    5  370     17.6
# 97    0.0   2.89     0  0.4450  6.163   69.6  3.4952    2  276     18.0
# 316   0.0   9.90     0  0.5440  5.705   77.7  3.9450    4  304     18.4
# 31    0.0   8.14     0  0.5380  5.713   94.1  4.2330    4  307     21.0
# 294   0.0  13.92     0  0.4370  6.127   18.4  5.5027    4  289     16.0
# 414   0.0  18.10     0  0.5970  5.155  100.0  1.5894   24  666     20.2
# 201  95.0   1.47     0  0.4030  7.135   13.9  7.6534    3  402     17.0
# 32    0.0   8.14     0  0.5380  6.072  100.0  4.1750    4  307     21.0
# 500   0.0   9.69     0  0.5850  5.569   73.5  2.3999    6  391     19.2
# 137   0.0  21.89     0  0.6240  5.942   93.5  1.9669    4  437     21.2
# 119   0.0  10.01     0  0.5470  5.872   73.1  2.4775    6  432     17.8
# 103   0.0   8.56     0  0.5200  6.405   85.4  2.7147    5  384     20.9
# 312   0.0   9.90     0  0.5440  6.122   52.8  2.6403    4  304     18.4
# ..    ...    ...   ...     ...    ...    ...     ...  ...  ...      ...
# 261  20.0   3.97     0  0.6470  7.203   81.8  2.1121    5  264     13.0
# 284  90.0   1.21     1  0.4010  7.923   24.8  5.8850    1  198     13.6
# 504   0.0  11.93     0  0.5730  6.976   91.0  2.1675    1  273     21.0
# 282  20.0   3.33     0  0.4429  6.968   37.2  5.2447    5  216     14.9
# 249  22.0   5.86     0  0.4310  6.433   49.1  7.8265    7  330     19.1
# 86    0.0   4.49     0  0.4490  6.630   56.1  4.4377    3  247     18.5
# 73    0.0  10.81     0  0.4130  6.065    7.8  5.2873    4  305     19.2
# 358   0.0  18.10     1  0.7700  6.395   91.0  2.5052   24  666     20.2
# 384   0.0  18.10     0  0.7000  5.520  100.0  1.5331   24  666     20.2
# 39    0.0   5.96     0  0.4990  5.966   30.2  3.8473    5  279     19.2
# 234   0.0   6.20     0  0.5070  8.247   70.4  3.6519    8  307     17.4
# 429   0.0  18.10     0  0.6790  6.193   78.1  1.9356   24  666     20.2
# 286  55.0   2.25     0  0.3890  6.453   31.9  7.3073    1  300     15.3
# 453   0.0  18.10     0  0.7130  6.297   91.8  2.3682   24  666     20.2
# 392   0.0  18.10     0  0.7000  6.051   82.5  2.1678   24  666     20.2
# 470   0.0  18.10     0  0.5800  5.713   56.7  2.8237   24  666     20.2
# 217   0.0  13.89     1  0.5500  5.888   56.0  3.1121    5  276     16.4
# 187   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193     17.8
# 223   0.0   6.20     1  0.5070  6.879   77.7  3.2721    8  307     17.4
# 148   0.0  19.58     0  0.8710  4.926   95.7  1.4608    5  403     14.7
# 128   0.0  21.89     0  0.6240  5.693   96.0  1.7883    4  437     21.2
# 321   0.0   7.38     0  0.4930  6.426   52.3  4.5404    5  287     19.6
# 176   0.0   4.05     0  0.5100  6.546   33.1  3.1323    5  296     16.6
# 506   0.0  11.93     0  0.5730  6.030   80.8  2.5050    1  273     21.0
# 35    0.0   8.14     0  0.5380  6.096   96.9  3.7598    4  307     21.0
# 283  20.0   3.33     1  0.4429  7.645   49.7  5.2119    5  216     14.9
# 107   0.0   8.56     0  0.5200  5.836   91.9  2.2110    5  384     20.9
# 159   0.0  19.58     0  0.6050  6.066  100.0  1.7573    5  403     14.7
# 418   0.0  18.10     0  0.6790  5.304   89.1  1.6475   24  666     20.2
# 151   0.0  19.58     0  0.8710  6.122   97.3  1.6180    5  403     14.7
#
#       black  lstat
# ID
# 40   395.63   4.32
# 441  391.45  22.11
# 454  375.87  16.74
# 84   390.64   7.51
# 262  388.37   7.26
# 16   395.62   8.47
# 341  396.90   9.29
# 343  389.96   8.65
# 121  389.15  14.37
# 225  385.05   4.14
# 61   395.11  13.15
# 473  393.37  14.36
# 155  321.02  15.12
# 227  387.38   3.13
# 289  396.90   7.60
# 231  378.35  11.65
# 179  391.27   6.92
# 344  396.90   7.18
# 97   391.83  11.34
# 316  396.42  11.50
# 31   360.17  22.60
# 294  396.90   8.58
# 414  210.97  20.08
# 201  384.30   4.45
# 32   376.73  13.04
# 500  395.77  15.10
# 137  378.25  16.90
# 119  338.63  15.37
# 103   70.80  10.63
# 312  396.90   5.98
# ..      ...    ...
# 261  392.80   9.59
# 284  395.52   3.16
# 504  396.90   5.64
# 282  392.23   4.59
# 249  374.71   9.52
# 86   392.30   6.53
# 73   390.91   5.52
# 358  391.34  13.27
# 384  396.90  24.56
# 39   393.43  10.13
# 234  378.95   3.95
# 429   96.73  21.52
# 286  394.72   8.23
# 453  385.09  17.27
# 392  378.38  18.76
# 470  396.90  14.76
# 217  392.80  13.51
# 187  392.63   4.45
# 223  390.39   9.93
# 148  391.71  29.53
# 128  392.11  17.19
# 321  396.90   7.20
# 176  390.96   5.33
# 506  396.90   7.88
# 35   248.31  20.34
# 283  377.07   3.01
# 107  395.67  18.66
# 159  353.89   6.43
# 418  127.36  26.64
# 151  372.80  14.10
#
# [233 rows x 12 columns]

# %%
for i in range(len(col_list)):
    feature_list=[]
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=reject_cols(X_train,feature_list)
        new_X_test=reject_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['crim']
# keep_col_list :  ['zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.698351347173638
# RMSE for test: 3.6315823476361473
# Accuracies: Train: 0.9158806711503036,    Test: 0.8279292565978139
#
#
#
# ['zn']
# keep_col_list :  ['crim', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.620901351823035
# RMSE for test: 3.4134126665270785
# Accuracies: Train: 0.9206402751661438,    Test: 0.8479827633742489
#
#
#
# ['indus']
# keep_col_list :  ['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.6091151307709457
# RMSE for test: 3.365755838603719
# Accuracies: Train: 0.9213524333071822,    Test: 0.8521979499568293
#
#
#
# ['chas']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.717092883429657
# RMSE for test: 3.2835652698213282
# Accuracies: Train: 0.9147081030398525,    Test: 0.8593283604797712
#
#
#
# ['nox']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.7300579379009364
# RMSE for test: 3.7256996124184365
# Accuracies: Train: 0.9138921924881857,    Test: 0.818894801999838
#
#
#
# ['rm']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 3.4600257084985215
# RMSE for test: 4.4862183470459644
# Accuracies: Train: 0.8616887663437831,    Test: 0.7374112858918036
#
#
#
# ['age']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.7797952986501926
# RMSE for test: 3.698778963570865
# Accuracies: Train: 0.9107261147740244,    Test: 0.8215025566211279
#
#
#
# ['dis']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.8381386725609152
# RMSE for test: 3.9335228790335774
# Accuracies: Train: 0.9069393618076111,    Test: 0.7981268297647506
#
#
#
# ['rad']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.714279544967051
# RMSE for test: 3.3991955959765097
# Accuracies: Train: 0.914884637856434,    Test: 0.8492464482207109
#
#
#
# ['tax']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.673013046444565
# RMSE for test: 3.6052471366546994
# Accuracies: Train: 0.9174530634410697,    Test: 0.8304158248476458
#
#
#
# ['ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'black', 'lstat']
# 0.0265
# RMSE for train: 2.66385159749324
# RMSE for test: 4.143232435663751
# Accuracies: Train: 0.9180179342834461,    Test: 0.7760279433163431
#
#
#
# ['black']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.7376992717846726
# RMSE for test: 3.2418890611181914
# Accuracies: Train: 0.9134094925959059,    Test: 0.8628766103938692
#
#
#
# ['lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black']
# 0.0265
# RMSE for train: 3.406372009806694
# RMSE for test: 4.4811018328532475
# Accuracies: Train: 0.8659450192408851,    Test: 0.738009907103849

# %%
for i in range(len(col_list)):
    feature_list=['black']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=reject_cols(X_train,feature_list)
        new_X_test=reject_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['black', 'crim']
# keep_col_list :  ['zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.883575451971911
# RMSE for test: 3.518373150678726
# Accuracies: Train: 0.9039358281736203,    Test: 0.8384901410424676
#
#
#
# ['black', 'zn']
# keep_col_list :  ['crim', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.782216367800053
# RMSE for test: 3.195998389696819
# Accuracies: Train: 0.9105705404606438,    Test: 0.86673124338354
#
#
#
# ['black', 'indus']
# keep_col_list :  ['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.7863014075542774
# RMSE for test: 3.225453668920607
# Accuracies: Train: 0.9103077348085453,    Test: 0.8642634338892745
#
#
#
# ['black', 'chas']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.900828681250431
# RMSE for test: 3.0364184484125043
# Accuracies: Train: 0.9027828321086242,    Test: 0.8797075182217654
#
#
#
# ['black', 'nox']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.870138008346569
# RMSE for test: 3.5399155565780918
# Accuracies: Train: 0.9048290589714582,    Test: 0.8365062908900087
#
#
#
# ['black', 'rm']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.609244726007147
# RMSE for test: 4.233558525372904
# Accuracies: Train: 0.8495017448887059,    Test: 0.7661559209690307
#
#
#
# ['black', 'age']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.9284508907280635
# RMSE for test: 3.405906183808952
# Accuracies: Train: 0.9009225787269632,    Test: 0.8486506345930963
#
#
#
# ['black', 'dis']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.9476666098187665
# RMSE for test: 3.6640883441656986
# Accuracies: Train: 0.8996180732212378,    Test: 0.8248350881752836
#
#
#
# ['black', 'rad']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.8866645202233987
# RMSE for test: 3.1509042366541045
# Accuracies: Train: 0.9037298979066553,    Test: 0.8704654411260078
#
#
#
# ['black', 'tax']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.8401430080888748
# RMSE for test: 3.396004799788089
# Accuracies: Train: 0.9068078737950946,    Test: 0.8495293375563299
#
#
#
# ['black', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'lstat']
# 0.0265
# RMSE for train: 2.8220712438687423
# RMSE for test: 3.9154574805322833
# Accuracies: Train: 0.9079900593651445,    Test: 0.7999768480910783
#
#
#
# ['black', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio']
# 0.0265
# RMSE for train: 3.6038262107212002
# RMSE for test: 4.629991533726172
# Accuracies: Train: 0.8499532880922053,    Test: 0.7203108391499295

# %%
for i in range(len(col_list)):
    feature_list=['black','chas']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=reject_cols(X_train,feature_list)
        new_X_test=reject_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['black', 'chas', 'crim']
# keep_col_list :  ['zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.0004462531531026
# RMSE for test: 3.2630285333908113
# Accuracies: Train: 0.8959910991137499,    Test: 0.86108249165306
#
#
#
# ['black', 'chas', 'zn']
# keep_col_list :  ['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.957319904649346
# RMSE for test: 3.0148500615308875
# Accuracies: Train: 0.8989595163516295,    Test: 0.8814103797401648
#
#
#
# ['black', 'chas', 'indus']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 2.947929133826009
# RMSE for test: 3.0198422527029214
# Accuracies: Train: 0.8996001920679955,    Test: 0.8810173172672726
#
#
#
# ['black', 'chas', 'nox']
# keep_col_list :  ['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.0011621178427466
# RMSE for test: 3.146134318034781
# Accuracies: Train: 0.89594146304272,    Test: 0.8708573296664068
#
#
#
# ['black', 'chas', 'rm']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.737992581907171
# RMSE for test: 4.241088974773853
# Accuracies: Train: 0.8385731865181995,    Test: 0.7653232799926121
#
#
#
# ['black', 'chas', 'age']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.068155967929289
# RMSE for test: 3.1374369035280405
# Accuracies: Train: 0.8912438889400586,    Test: 0.8715703664797478
#
#
#
# ['black', 'chas', 'dis']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'rad', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.2078299131798906
# RMSE for test: 3.459978974992609
# Accuracies: Train: 0.881116530950919,    Test: 0.8438067859390201
#
#
#
# ['black', 'chas', 'rad']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.0604604941965947
# RMSE for test: 2.918359902692361
# Accuracies: Train: 0.8917887635952263,    Test: 0.8888798186713702
#
#
#
# ['black', 'chas', 'tax']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.0180124424064507
# RMSE for test: 3.2143054205773365
# Accuracies: Train: 0.894769688624317,    Test: 0.8652001144292307
#
#
#
# ['black', 'chas', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'lstat']
# 0.0265
# RMSE for train: 2.994568398186932
# RMSE for test: 3.4229042880171985
# Accuracies: Train: 0.8963982055029035,    Test: 0.847136164195219
#
#
#
# ['black', 'chas', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio']
# 0.0265
# RMSE for train: 4.316099663429643
# RMSE for test: 4.116266826121241
# Accuracies: Train: 0.7847804432805342,    Test: 0.7789338335315423

# %%
for i in range(len(col_list)):
    feature_list=['black','chas','rad']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=reject_cols(X_train,feature_list)
        new_X_test=reject_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['black', 'chas', 'rad', 'crim']
# keep_col_list :  ['zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.1430403723135534
# RMSE for test: 3.0908119014346886
# Accuracies: Train: 0.885870287628337,    Test: 0.8753591523393398
#
#
#
# ['black', 'chas', 'rad', 'zn']
# keep_col_list :  ['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.121110897551907
# RMSE for test: 2.9634533661049822
# Accuracies: Train: 0.8874573327347409,    Test: 0.8854193089980348
#
#
#
# ['black', 'chas', 'rad', 'indus']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.118177573132445
# RMSE for test: 2.881053370811167
# Accuracies: Train: 0.8876687760535401,    Test: 0.8917026451210622
#
#
#
# ['black', 'chas', 'rad', 'nox']
# keep_col_list :  ['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.13902936550149
# RMSE for test: 3.046647700325798
# Accuracies: Train: 0.8861613961752333,    Test: 0.878895657266772
#
#
#
# ['black', 'chas', 'rad', 'rm']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 4.011786898163717
# RMSE for test: 4.053800448228329
# Accuracies: Train: 0.8140592771124011,    Test: 0.7855924990380841
#
#
#
# ['black', 'chas', 'rad', 'age']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.212179709306396
# RMSE for test: 3.0011357479877514
# Accuracies: Train: 0.8807939019636901,    Test: 0.8824868353357558
#
#
#
# ['black', 'chas', 'rad', 'dis']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.4045265676463123
# RMSE for test: 3.17423578667144
# Accuracies: Train: 0.8660902316247195,    Test: 0.8685400056109782
#
#
#
# ['black', 'chas', 'rad', 'tax']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.3269410816469303
# RMSE for test: 3.18958032521346
# Accuracies: Train: 0.8721240057947488,    Test: 0.8672659549532857
#
#
#
# ['black', 'chas', 'rad', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'lstat']
# 0.0265
# RMSE for train: 3.202008425620619
# RMSE for test: 3.3955356248392197
# Accuracies: Train: 0.8815476327683441,    Test: 0.8495709112247151
#
#
#
# ['black', 'chas', 'rad', 'lstat']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio']
# 0.0265
# RMSE for train: 4.447067954731372
# RMSE for test: 4.350304139579707
# Accuracies: Train: 0.7715209757586375,    Test: 0.7530810149112039

# %%
for i in range(len(col_list)):
    feature_list=['black','chas','rad','indus']
    curr_feature_name=col_list[i]
    
    if curr_feature_name not in feature_list:
        feature_list.append(curr_feature_name)
        print(feature_list)

        new_X_train=reject_cols(X_train,feature_list)
        new_X_test=reject_cols(X_test,feature_list)
        my_elas_func(new_X_train,y_train,new_X_test,y_test)
# Out:
# ['black', 'chas', 'rad', 'indus', 'crim']
# keep_col_list :  ['zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.196207625172519
# RMSE for test: 2.934964104263578
# Accuracies: Train: 0.8819764237377498,    Test: 0.8876117703484109
#
#
#
# ['black', 'chas', 'rad', 'indus', 'zn']
# keep_col_list :  ['crim', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.190816790295037
# RMSE for test: 2.885078307211169
# Accuracies: Train: 0.8823742133239402,    Test: 0.8913998430645871
#
#
#
# ['black', 'chas', 'rad', 'indus', 'nox']
# keep_col_list :  ['crim', 'zn', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.2012994279632045
# RMSE for test: 2.9197417452479186
# Accuracies: Train: 0.8816000830694716,    Test: 0.888774563011655
#
#
#
# ['black', 'chas', 'rad', 'indus', 'rm']
# keep_col_list :  ['crim', 'zn', 'nox', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'age', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 4.095830670285545
# RMSE for test: 3.996715760653265
# Accuracies: Train: 0.8061870503563586,    Test: 0.7915884572775629
#
#
#
# ['black', 'chas', 'rad', 'indus', 'age']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'dis', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'dis', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.2694300406336714
# RMSE for test: 2.991858979059176
# Accuracies: Train: 0.8765068407255154,    Test: 0.8832121991339595
#
#
#
# ['black', 'chas', 'rad', 'indus', 'dis']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'tax', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'tax', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.4506003624092223
# RMSE for test: 3.1479697402011424
# Accuracies: Train: 0.8624412784721318,    Test: 0.870706604721701
#
#
#
# ['black', 'chas', 'rad', 'indus', 'tax']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'ptratio', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'ptratio', 'lstat']
# 0.0265
# RMSE for train: 3.3861263556336114
# RMSE for test: 3.1267878089415104
# Accuracies: Train: 0.8675337860572052,    Test: 0.8724407191281468
#
#
#
# ['black', 'chas', 'rad', 'indus', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'lstat']
# 0.0265
# RMSE for train: 3.2843938365363954
# RMSE for test: 2.9256795787237695
# Accuracies: Train: 0.8753738265435518,    Test: 0.8883217081072291
#
#
#
# ['black', 'chas', 'rad', 'indus', 'lstat']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio']
# keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio']
# 0.0265
# RMSE for train: 4.537472411479591
# RMSE for test: 4.466160081963852
# Accuracies: Train: 0.7621370511773683,    Test: 0.7397541496848077

# %%
forward selection
['lstat', 'rm', 'ptratio', 'age', 'tax', 'dis', 'crim', 'nox', 'zn']
0.0265
RMSE for train: 3.118266535279123
RMSE for test: 2.882864876886123
Accuracies: Train: 0.8876623663035237,    Test: 0.8915664150919732

# %%
backward elimination
['black', 'chas', 'rad', 'indus']
keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
keep_col_list :  ['crim', 'zn', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'lstat']
0.0265
RMSE for train: 3.118177573132445
RMSE for test: 2.881053370811167
Accuracies: Train: 0.8876687760535401,    Test: 0.8917026451210622
